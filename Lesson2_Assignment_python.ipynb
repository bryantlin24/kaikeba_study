# %% [markdown]
# ![](https://img.kaikeba.com/web/kkb_index/img_index_logo.png)

# %% [markdown]
# # 基础课第一部分（python）第二次作业
#
# 同学们～大家好！又到了做作业的时间了！上次的作业有 print使用 和 安装Python Pycharm Anaconda 的教程，请确认安装软件好了～
# 本次作业有三个题目：
# - 1. 实现一周的记账功能
# - 2. 实现ATM机功能
# - 3. 词汇表生成及统计
#
# ## 1. 实现一周的记账功能
#
# 首先记录输入的7天的收入，然后记录输入的7天的支出。
# 然后打印出以下内容：
# - 7天的收入(list)
# - 7天的支出(list)
# - 每天的结余(dict)
# - 最终的结余

# %%
income = []
output = []
surplus = dict()
final_surplus = 0
for i in range(7):
    perday_income = input('周'+str(i+1)+'的收入：')
    perday_output = input('周'+str(i+1)+'的支出：')
    income.append(perday_income)
    output.append(perday_output)
    surplus[i+1] = int(income[i]) -int(output[i])
    final_surplus = surplus[i+1] + final_surplus
    print('周'+str(i+1)+'的结余',final_surplus)
print('七天的收入',income)
print('七天的支出',output)
print('每天的结余',surplus)
print('最终的结余',final_surplus)
# Out:
# 周1的收入：20
# 周1的支出：10
# 周1的结余 10
# 周2的收入：30
# 周2的支出：10
# 周2的结余 30
# 周3的收入：40
# 周3的支出：10
# 周3的结余 60
# 周4的收入：50
# 周4的支出：10
# 周4的结余 100
# 周5的收入：60
# 周5的支出：10
# 周5的结余 150
# 周6的收入：70
# 周6的支出：10
# 周6的结余 210
# 周7的收入：80
# 周7的支出：10
# 周7的结余 280
# 七天的收入 ['20', '30', '40', '50', '60', '70', '80']
# 七天的支出 ['10', '10', '10', '10', '10', '10', '10']
# 每天的结余 {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60, 7: 70}
# 最终的结余 280

# %% [markdown]
# ## 2. 实现ATM机器
# - 查询余额
# - 存款
# - 取款
# - 退出

# %%
balance =0
while (True):
    print('请输入：1.查询余额  2.存款  3.取款  4.退出')
    button = int(input())
    if button == 1:
        print('余额为',balance)
    elif button == 2:
        income = int(input('输入存款金额：'))
        balance = balance + income
    elif button == 3:
        output = int(input('输入取款金额：'))
        balance = balance - output
        if balance < 0:
            print('余额不足，操作失败')
            balance = balance + output
    elif button == 4:
        print('退出')
        break
# Out:
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 1
# 余额为 0
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 30
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 2
# 输入存款金额：80
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 1
# 余额为 80
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 2
# 输入存款金额：30
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 1
# 余额为 110
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 3
# 输入取款金额：5
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 1
# 余额为 105
# 请输入：1.查询余额  2.存款  3.取款  4.退出
# 4
# 退出

# %% [markdown]
# ## 3. 词汇表生成及统计
#
# 下面是一段[文本](http://baijiahao.baidu.com/s?id=1646569900805781240&wfr=spider&for=pc)：
#
# > 2019年十月一日上午，庆祝中华人民共和国成立70周年阅兵式在首都北京盛大举行，59个阅兵方阵，580台受阅装备，1.5万人的参阅队伍接受了全国人民的检阅。阅兵装备方队展示的武器装备皆为国产现役主战装备，40%为首次展示。其中近些年来广受全球关注的东风41洲际弹道导弹，巨浪二潜射弹道导弹，东风17高超音速武器系统终于揭幕亮剑，以"不怒自威"的形象向世界展示中国捍卫和平的意志与力量。相较于其他首度公开亮相的武器装备，这三款武器多年来传闻不断，备受关注，并因其"大国基石"的地位而被公众赋予特殊的期待，这三款武器装备实力究竟如何，又各自承担着怎样的历史"使命"呢？本报特约相关领域军事专家，为大家详细解读这三款彰显国威，震撼世界的国之重器。
#
# 经过分词后得到以下单词，通过空格分隔。
#
# ```python
# text = '2019 年 十月 一日 上午 ， 庆祝 中华人民共和国 成立 70 周年 阅兵式 在 首都北京 盛大举行 ， 59 个 阅兵 方阵 ， 580 台受 阅 装备 ， 1.5 万人 的 参阅 队伍 接受 了 全国 人民 的 检阅 。 阅兵 装备 方队 展示 的 武器装备 皆 为 国产 现役 主战 装备 ， 40% 为 首次 展示 。 其中 近些年来 广受 全球 关注 的 东风 41 洲际 弹道导弹 ， 巨浪 二潜射 弹道导弹 ， 东风 17 高超音速 武器 系统 终于 揭幕 亮剑 ， 以 " 不怒 自威 " 的 形象 向 世界 展示 中国 捍卫 和平 的 意志 与 力量 。 相较 于 其他 首度 公开 亮相 的 武器装备 ， 这 三款 武器 多年 来 传闻 不断 ， 备受 关注 ， 并 因 其 " 大国 基石 " 的 地位 而 被 公众 赋予 特殊 的 期待 ， 这 三款 武器装备 实力 究竟 如何 ， 又 各自 承担 着 怎样 的 历史 " 使命 " 呢 ？ 本报 特约 相关 领域 军事 专家 ， 为 大家 详细 解读 这 三款 彰显 国威 ， 震撼 世界 的 国 之 重器 。'
# ```
#
# 将文本生成词汇表(单词list)，单词对应ID的dict，以及ID对应单词的dict。
# 将你的程序变成一个盒子，
#
# 输入就是上面一段文本，
#
# 盒子内部：首先将文本转换成单词列表，再得到统计的单词表(去重)，然后得到单词ID相互对应的字典。
#
# 输出：词汇表，word2id, id2word
# 效果如下：
#
# ```python
# vocab = ['大家', '中国', '捍卫', ...}
# word2id = {'大家': 0, '中国': 1, '捍卫': 2, ...}
# id2word = {0: '大家', 1: '中国', 2: '捍卫', ...}
# ```

# %%
text = '2019 年 十月 一日 上午 ， 庆祝 中华人民共和国 成立 70 周年 阅兵式 在 首都北京 盛大举行 ， 59 个 阅兵 方阵 ， 580 台受 阅 装备 ， 1.5 万人 的 参阅 队伍 接受 了 全国 人民 的 检阅 。 阅兵 装备 方队 展示 的 武器装备 皆 为 国产 现役 主战 装备 ， 40% 为 首次 展示 。 其中 近些年来 广受 全球 关注 的 东风 41 洲际 弹道导弹 ， 巨浪 二潜射 弹道导弹 ， 东风 17 高超音速 武器 系统 终于 揭幕 亮剑 ， 以 " 不怒 自威 " 的 形象 向 世界 展示 中国 捍卫 和平 的 意志 与 力量 。 相较 于 其他 首度 公开 亮相 的 武器装备 ， 这 三款 武器 多年 来 传闻 不断 ， 备受 关注 ， 并 因 其 " 大国 基石 " 的 地位 而 被 公众 赋予 特殊 的 期待 ， 这 三款 武器装备 实力 究竟 如何 ， 又 各自 承担 着 怎样 的 历史 " 使命 " 呢 ？ 本报 特约 相关 领域 军事 专家 ， 为 大家 详细 解读 这 三款 彰显 国威 ， 震撼 世界 的 国 之 重器 。'
vocab = list(set(text.split()))
word2id = dict(zip(vocab,range(len(vocab))))
id2word = dict(zip(range(len(vocab)),vocab))
print('vocab=',vocab)
print('word2id=',word2id)
print('id2word=',id2word)
# Out:
# vocab= ['以', '580', '全国', '被', '装备', '庆祝', '检阅', '传闻', '40%', '历史', '本报', '队伍', '基石', '特约', '世界', '广受', '彰显', '特殊', '阅', '盛大举行', '并', '的', '2019', '因', '首度', '其', '"', '41', '。', '期待', '接受', '赋予', '其他', '系统', '国', '意志', '大国', '如何', '国威', '三款', '地位', '多年', '周年', '首都北京', '军事', '近些年来', '重器', '相较', '不断', '武器装备', '上午', '与', '实力', '相关', '70', '个', '东风', '59', '于', '解读', '亮剑', '各自', '为', '和平', '参阅', '武器', '皆', '方阵', '阅兵', '究竟', '方队', '又', '公众', '着', '洲际', '主战', '二潜射', '现役', '其中', '这', '使命', '公开', '详细', '巨浪', '不怒', '呢', '关注', '弹道导弹', '而', '大家', '之', '首次', '万人', '全球', '终于', '成立', '形象', '专家', '国产', '在', '捍卫', '阅兵式', '自威', '承担', '十月', '力量', '中国', '亮相', '向', '领域', '备受', '，', '怎样', '了', '震撼', '高超音速', '人民', '一日', '台受', '揭幕', '年', '17', '中华人民共和国', '？', '展示', '来', '1.5']
# word2id= {'以': 0, '580': 1, '全国': 2, '被': 3, '装备': 4, '庆祝': 5, '检阅': 6, '传闻': 7, '40%': 8, '历史': 9, '本报': 10, '队伍': 11, '基石': 12, '特约': 13, '世界': 14, '广受': 15, '彰显': 16, '特殊': 17, '阅': 18, '盛大举行': 19, '并': 20, '的': 21, '2019': 22, '因': 23, '首度': 24, '其': 25, '"': 26, '41': 27, '。': 28, '期待': 29, '接受': 30, '赋予': 31, '其他': 32, '系统': 33, '国': 34, '意志': 35, '大国': 36, '如何': 37, '国威': 38, '三款': 39, '地位': 40, '多年': 41, '周年': 42, '首都北京': 43, '军事': 44, '近些年来': 45, '重器': 46, '相较': 47, '不断': 48, '武器装备': 49, '上午': 50, '与': 51, '实力': 52, '相关': 53, '70': 54, '个': 55, '东风': 56, '59': 57, '于': 58, '解读': 59, '亮剑': 60, '各自': 61, '为': 62, '和平': 63, '参阅': 64, '武器': 65, '皆': 66, '方阵': 67, '阅兵': 68, '究竟': 69, '方队': 70, '又': 71, '公众': 72, '着': 73, '洲际': 74, '主战': 75, '二潜射': 76, '现役': 77, '其中': 78, '这': 79, '使命': 80, '公开': 81, '详细': 82, '巨浪': 83, '不怒': 84, '呢': 85, '关注': 86, '弹道导弹': 87, '而': 88, '大家': 89, '之': 90, '首次': 91, '万人': 92, '全球': 93, '终于': 94, '成立': 95, '形象': 96, '专家': 97, '国产': 98, '在': 99, '捍卫': 100, '阅兵式': 101, '自威': 102, '承担': 103, '十月': 104, '力量': 105, '中国': 106, '亮相': 107, '向': 108, '领域': 109, '备受': 110, '，': 111, '怎样': 112, '了': 113, '震撼': 114, '高超音速': 115, '人民': 116, '一日': 117, '台受': 118, '揭幕': 119, '年': 120, '17': 121, '中华人民共和国': 122, '？': 123, '展示': 124, '来': 125, '1.5': 126}
# id2word= {0: '以', 1: '580', 2: '全国', 3: '被', 4: '装备', 5: '庆祝', 6: '检阅', 7: '传闻', 8: '40%', 9: '历史', 10: '本报', 11: '队伍', 12: '基石', 13: '特约', 14: '世界', 15: '广受', 16: '彰显', 17: '特殊', 18: '阅', 19: '盛大举行', 20: '并', 21: '的', 22: '2019', 23: '因', 24: '首度', 25: '其', 26: '"', 27: '41', 28: '。', 29: '期待', 30: '接受', 31: '赋予', 32: '其他', 33: '系统', 34: '国', 35: '意志', 36: '大国', 37: '如何', 38: '国威', 39: '三款', 40: '地位', 41: '多年', 42: '周年', 43: '首都北京', 44: '军事', 45: '近些年来', 46: '重器', 47: '相较', 48: '不断', 49: '武器装备', 50: '上午', 51: '与', 52: '实力', 53: '相关', 54: '70', 55: '个', 56: '东风', 57: '59', 58: '于', 59: '解读', 60: '亮剑', 61: '各自', 62: '为', 63: '和平', 64: '参阅', 65: '武器', 66: '皆', 67: '方阵', 68: '阅兵', 69: '究竟', 70: '方队', 71: '又', 72: '公众', 73: '着', 74: '洲际', 75: '主战', 76: '二潜射', 77: '现役', 78: '其中', 79: '这', 80: '使命', 81: '公开', 82: '详细', 83: '巨浪', 84: '不怒', 85: '呢', 86: '关注', 87: '弹道导弹', 88: '而', 89: '大家', 90: '之', 91: '首次', 92: '万人', 93: '全球', 94: '终于', 95: '成立', 96: '形象', 97: '专家', 98: '国产', 99: '在', 100: '捍卫', 101: '阅兵式', 102: '自威', 103: '承担', 104: '十月', 105: '力量', 106: '中国', 107: '亮相', 108: '向', 109: '领域', 110: '备受', 111: '，', 112: '怎样', 113: '了', 114: '震撼', 115: '高超音速', 116: '人民', 117: '一日', 118: '台受', 119: '揭幕', 120: '年', 121: '17', 122: '中华人民共和国', 123: '？', 124: '展示', 125: '来', 126: '1.5'}

# %% [markdown]
# 本次的作业就到这里了！祝大家学习进步！
# ![image alt <](http://5b0988e595225.cdn.sohucs.com/images/20190420/1d1070881fd540db817b2a3bdd967f37.gif)
